# %%
import pandas as pd

# %%
df = pd.read_csv('/home/motovilovil/Robotics/robotics_project/mimic-video/eval_outputs/libero_spatial_one_5eps_nograph/metrics/episodes_metrics.csv')
df.head()
# Out:
#    action_delta_norm_max  action_delta_norm_mean  action_delta_norm_min  \
# 0               0.442488                0.148515               0.015835
# 1               1.042690                0.146510               0.016556
# 2               0.580485                0.129116               0.010376
# 3               0.879113                0.118363               0.012442
# 4               0.421606                0.139787               0.017724
#
#    action_delta_norm_p05  action_delta_norm_p25  action_delta_norm_p50  \
# 0               0.035267               0.083701               0.128768
# 1               0.035491               0.079526               0.125459
# 2               0.034831               0.064491               0.113379
# 3               0.032069               0.056724               0.090896
# 4               0.036431               0.070648               0.126674
#
#    action_delta_norm_p75  action_delta_norm_p95  action_delta_norm_std  \
# ...
